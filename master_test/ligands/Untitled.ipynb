# %%
import pandas as pd

# %%
pbs = pd.read_csv("peptideBatch.tsv", sep="\t")

# %%
pbs[pbs.duplicated()]
# Out:
#            sid labeling  concentration concentration_unit  \
# 203     P010-1      NaN           1.00            Stock 1
# 204   P010-0.5      NaN           0.50            Stock 1
# 205  P010-0.25      NaN           0.25            Stock 1
# 206     P011-1      NaN           1.00            Stock 1
# 207   P011-0.5      NaN           0.50            Stock 1
# 208  P011-0.25      NaN           0.25            Stock 1
# 209     P012-1      NaN           1.00            Stock 1
# 210   P012-0.5      NaN           0.50            Stock 1
# 211  P012-0.25      NaN           0.25            Stock 1
# 212     P013-1      NaN           1.00            Stock 1
# 213   P013-0.5      NaN           0.50            Stock 1
# 214  P013-0.25      NaN           0.25            Stock 1
# 215     P014-1      NaN           1.00            Stock 1
# 216   P014-0.5      NaN           0.50            Stock 1
# 217  P014-0.25      NaN           0.25            Stock 1
# ...
